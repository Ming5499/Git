# %%
import pandas as pd

#df = pd.read_parquet('yellow_tripdata_2021-01.parquet')
#df.to_csv('uber_data_2021.csv')

# %%
import matplotlib.pyplot as plt

# %%
uber = pd.read_csv('uber_data_2021.csv')

# %%
uber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 641270 entries, 0 to 641269
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             641270 non-null  int64
#  1   VendorID               641270 non-null  int64
#  2   tpep_pickup_datetime   641270 non-null  object
#  3   tpep_dropoff_datetime  641270 non-null  object
#  4   passenger_count        641270 non-null  float64
#  5   trip_distance          641270 non-null  float64
#  6   RatecodeID             641270 non-null  float64
#  7   store_and_fwd_flag     641270 non-null  object
#  8   PULocationID           641270 non-null  int64
#  9   DOLocationID           641270 non-null  int64
#  10  payment_type           641270 non-null  int64
#  11  fare_amount            641270 non-null  float64
#  12  extra                  641270 non-null  float64
#  13  mta_tax                641270 non-null  float64
# ...

# %%
import numpy as np

# Replace NaN values with a default value (e.g., 0)
df['passenger_count'] = df['passenger_count'].fillna(0).astype('int64')
df['RatecodeID'] = df['RatecodeID'].fillna(0).astype('int64')

# %%
#Change type
df['passenger_count'] = df['passenger_count'].astype('int64')
df['RatecodeID'] = df['RatecodeID'].astype('int64')

# %%
uber_subset = uber[['']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Admin\Desktop\VSCode\Git\uber-project\data_exploration.ipynb Cell 7 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/VSCode/Git/uber-project/data_exploration.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> uber_subset = uber[['']]
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
# ...

# %%
uber.hist(bins=60,figsize=(20,10))
# Out:
# array([[<Axes: title={'center': 'Unnamed: 0'}>,
#         <Axes: title={'center': 'VendorID'}>,
#         <Axes: title={'center': 'passenger_count'}>,
#         <Axes: title={'center': 'trip_distance'}>],
#        [<Axes: title={'center': 'RatecodeID'}>,
#         <Axes: title={'center': 'PULocationID'}>,
#         <Axes: title={'center': 'DOLocationID'}>,
#         <Axes: title={'center': 'payment_type'}>],
#        [<Axes: title={'center': 'fare_amount'}>,
#         <Axes: title={'center': 'extra'}>,
#         <Axes: title={'center': 'mta_tax'}>,
#         <Axes: title={'center': 'tip_amount'}>],
#        [<Axes: title={'center': 'tolls_amount'}>,
#         <Axes: title={'center': 'improvement_surcharge'}>,
#         <Axes: title={'center': 'total_amount'}>,
#         <Axes: title={'center': 'congestion_surcharge'}>],
#        [<Axes: title={'center': 'airport_fee'}>, <Axes: >, <Axes: >,
#         <Axes: >]], dtype=object)

# %%
uber['VendorID'].value_counts()
# Out:
# 2    436347
# 1    204923
# Name: VendorID, dtype: int64

# %%
uber['VendorID'].hist(bins=10,figsize=(20,10))
# Out:
# <Axes: >

# %%
uber['passenger_count'].value_counts()
# Out:
# 1.0    485446
# 2.0     81846
# 3.0     22707
# 5.0     15699
# 0.0     13738
# 6.0     13090
# 4.0      8741
# 7.0         2
# 8.0         1
# Name: passenger_count, dtype: int64

# %%
uber['airport_fee'].value_counts()
# Out:
# 0.0    5
# Name: airport_fee, dtype: int64

# %%
uber.isna().sum()
# Out:
# Unnamed: 0                    0
# VendorID                      0
# tpep_pickup_datetime          0
# tpep_dropoff_datetime         0
# passenger_count               0
# trip_distance                 0
# RatecodeID                    0
# store_and_fwd_flag            0
# PULocationID                  0
# DOLocationID                  0
# payment_type                  0
# fare_amount                   0
# extra                         0
# mta_tax                       0
# tip_amount                    0
# tolls_amount                  0
# improvement_surcharge         0
# total_amount                  0
# congestion_surcharge          0
# airport_fee              641265
# dtype: int64
