# %%
import psycopg2
import pandas as pd

# %%
def create_database():
    #connect to default database
    conn = psycopg2.connect("host=127.0.0.1 dbname=postgres user=postgres password=123456")
    conn.set_session(autocommit=True)
    cur = conn.cursor()
    
    
    #create sparkify database with UTF8 encoding
    cur.execute("DROP DATABASE IF EXISTS accounts")
    cur.execute("CREATE DATABASE accounts")
    
    #close connection to default database
    conn.close()
    
    #connect to sparkify database
    conn = psycopg2.connect("host=127.0.0.1 dbname=accounts user=postgres password=123456")
    cur = conn.cursor()
    
    return cur, conn

# %%
conn.commit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Admin\Desktop\VSCode\Git\wealth-project\connect-database.ipynb Cell 3 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/VSCode/Git/wealth-project/connect-database.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> conn.commit()
#
# NameError: name 'conn' is not defined

# %%
cur , conn = create_database()

# %%
AccountsCountry = pd.read_csv("C:/Users/Admin/Desktop/Project-DE/Wealth-project/Wealth-AccountsCountry.csv") 
AccountsCountry.head()
# Out:
#   Code                  Long Name         Income Group  \
# 0  ALB        Republic of Albania  Upper middle income
# 1  ARG         Argentine Republic  Upper middle income
# 2  ARM        Republic of Armenia  Upper middle income
# 3  AUS  Commonwealth of Australia          High income
# 4  AUT        Republic of Austria          High income
#
#                       Region Lending category Other groups      Currency Unit  \
# 0      Europe & Central Asia             IBRD          NaN       Albanian lek
# 1  Latin America & Caribbean             IBRD          NaN     Argentine peso
# 2      Europe & Central Asia             IBRD          NaN      Armenian dram
# 3        East Asia & Pacific              NaN          NaN  Australian dollar
# 4      Europe & Central Asia              NaN    Euro area               Euro
#
#                             Latest population census  \
# 0                                    2020 (expected)
# 1                                    2020 (expected)
# 2                                    2020 (expected)
# 3                                               2016
# 4  2011. Population figures compiled from adminis...
#
#                       Latest household survey  \
# 0      Demographic and Health Survey, 2017/18
# 1  Multiple Indicator Cluster Survey, 2019/20
# 2      Demographic and Health Survey, 2015/16
# 3                                         NaN
# 4                                         NaN
#
#                                        Special Notes  ...  \
# 0                                                NaN  ...
# 1                                                NaN  ...
# 2                                                NaN  ...
# 3  Fiscal year end: June 30; reporting period for...  ...
# 4  A simple multiplier is used to convert the nat...  ...
#
#    Source of most recent Income and expenditure data  \
# 0  Living Standards Measurement Study Survey (LSM...
# 1            Integrated household survey (IHS), 2016
# 2            Integrated household survey (IHS), 2016
# 3     Expenditure survey/budget survey (ES/BS), 2010
# 4                           Income survey (IS), 2015
#
#    Vital registration complete Latest agricultural census  \
# 0                          Yes                       2012
# 1                          Yes                       2008
# 2                          Yes                       2014
# 3                          Yes                  2015-2016
# 4                          Yes                       2010
#
#   Latest industrial data Latest trade data Latest water withdrawal data  \
# 0                 2013.0            2018.0                       2006.0
# 1                 2002.0            2018.0                       2011.0
# 2                    NaN            2018.0                       2012.0
# 3                 2013.0            2018.0                       2013.0
# 4                 2014.0            2018.0                       2010.0
#
#   2-alpha code WB-2 code Table Name Short Name
# 0           AL        AL    Albania    Albania
# 1           AR        AR  Argentina  Argentina
# 2           AM        AM    Armenia    Armenia
# 3           AU        AU  Australia  Australia
# 4           AT        AT    Austria    Austria
#
# [5 rows x 31 columns]

# %%
AccountsCountry_clean = AccountsCountry[['Code','Short Name','Table Name','Long Name','Currency Unit']]
AccountsCountry_clean.head()
# Out:
#   Code Short Name Table Name                  Long Name      Currency Unit
# 0  ALB    Albania    Albania        Republic of Albania       Albanian lek
# 1  ARG  Argentina  Argentina         Argentine Republic     Argentine peso
# 2  ARM    Armenia    Armenia        Republic of Armenia      Armenian dram
# 3  AUS  Australia  Australia  Commonwealth of Australia  Australian dollar
# 4  AUT    Austria    Austria        Republic of Austria               Euro

# %%
AccountsData = pd.read_csv("C:/Users/Admin/Desktop/Project-DE/Wealth-project/Wealth-AccountData.csv")
AccountsData.head()
# Out:
#   Country Name Country Code  \
# 0      Albania          ALB
# 1      Albania          ALB
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                          Series Name     Series Code  \
# 0                  Human capital (constant 2018 US$)       NW.HCA.TO
# 1       Human capital per capita (constant 2018 US$)       NW.HCA.PC
# 2  Human capital per capita, employed female (con...  NW.HCA.FEMP.PC
# 3  Human capital per capita, employed male (const...  NW.HCA.MEMP.PC
# 4  Human capital per capita, female (constant 201...  NW.HCA.FEMA.PC
#
#   1995 [YR1995] 1996 [YR1996] 1997 [YR1997] 1998 [YR1998] 1999 [YR1999]  \
# 0      4.49E+10      4.34E+10      3.71E+10      3.88E+10      4.22E+10
# 1      14072.79      13708.99       11794.1      12399.48      13573.26
# 2      3468.858      3355.549      2868.997      3013.391      3259.893
# 3      6507.931      6353.737      5466.692      5901.072       6492.73
# 4      4893.006      4737.857      4059.321      4191.445      4536.972
#
#   2000 [YR2000]  ... 2009 [YR2009] 2010 [YR2010] 2011 [YR2011] 2012 [YR2012]  \
# 0      4.36E+10  ...  6.610000e+10  6.810000e+10  6.850000e+10  7.080000e+10
# 1      14118.13  ...  2.258200e+04  2.336286e+04  2.359058e+04  2.439397e+04
# 2      3424.007  ...  2.825336e+03  2.889150e+03  2.848523e+03  2.930234e+03
# 3      6872.019  ...  1.525319e+04  1.578992e+04  1.579854e+04  1.647360e+04
# 4      4695.071  ...  3.529144e+03  3.613606e+03  3.603694e+03  3.683810e+03
#
#    2013 [YR2013]  2014 [YR2014]  2015 [YR2015]  2016 [YR2016]  2017 [YR2017]  \
# 0   7.160000e+10   7.250000e+10   7.370000e+10       7.57E+10       7.80E+10
# 1   2.473162e+04   2.509002e+04   2.559371e+04       26326.26       27160.86
# 2   2.954273e+03   2.957420e+03   2.987545e+03       3072.504       3178.417
# 3   1.681013e+04   1.699138e+04   1.730701e+04        17817.1       18445.94
# 4   3.696744e+03   3.719608e+03   3.767628e+03       3872.142       3992.188
#
#    2018 [YR2018]
# 0       8.12E+10
# 1       28333.68
# 2       3312.927
# 3       19245.19
# 4       4161.137
#
# [5 rows x 28 columns]

# %%
AccountsData.columns
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '1995 [YR1995]', '1996 [YR1996]', '1997 [YR1997]', '1998 [YR1998]',
#        '1999 [YR1999]', '2000 [YR2000]', '2001 [YR2001]', '2002 [YR2002]',
#        '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]',
#        '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]', '2010 [YR2010]',
#        '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]',
#        '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]'],
#       dtype='object')

# %%
AccountsSeries = pd.read_csv("C:/Users/Admin/Desktop/Project-DE/Wealth-project/Wealth-AccountSeries.csv")
AccountsSeries.head()
# Out:
#              Code                                     Indicator Name  \
# 0       NW.HCA.TO                  Human capital (constant 2018 US$)
# 1       NW.HCA.PC       Human capital per capita (constant 2018 US$)
# 2  NW.HCA.FEMP.PC  Human capital per capita, employed female (con...
# 3  NW.HCA.MEMP.PC  Human capital per capita, employed male (const...
# 4  NW.HCA.FEMA.PC  Human capital per capita, female (constant 201...
#
#                                      Long definition  \
# 0  Human capital is computed as the present value...
# 1  Human capital is computed as the present value...
# 2  Human capital is computed as the present value...
# 3  Human capital is computed as the present value...
# 4  Human capital is computed as the present value...
#
#                                               Source          Topic  \
# 0  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# 1  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# 2  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# 3  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# 4  World Bank. 2021. The Changing Wealth of Natio...  Human capital
#
#      Unit of measure Periodicity Reference period  \
# 0  Constant 2018 US$      Annual        1995-2018
# 1  Constant 2018 US$      Annual        1995-2018
# 2  Constant 2018 US$      Annual        1995-2018
# 3  Constant 2018 US$      Annual        1995-2018
# 4  Constant 2018 US$      Annual        1995-2018
#
#                  Statistical concept and methodology Previous Indicator Code  \
# 0  Total wealth is calculated by summing up estim...                     NaN
# 1  Total wealth is calculated by summing up estim...                     NaN
# 2  Total wealth is calculated by summing up estim...                     NaN
# 3  Total wealth is calculated by summing up estim...                     NaN
# 4  Total wealth is calculated by summing up estim...                     NaN
#
#   Previous Indicator Name
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN

# %%
AccountsSeries.columns
# Out:
# Index(['Code', 'Indicator Name', 'Long definition', 'Source', 'Topic',
#        'Unit of measure', 'Periodicity', 'Reference period',
#        'Statistical concept and methodology', 'Previous Indicator Code',
#        'Previous Indicator Name'],
#       dtype='object')

# %%
AccountsSeries1 = AccountsSeries[['Code','Topic','Indicator Name','Source']]
AccountsSeries1.head()
# Out:
#              Code          Topic  \
# 0       NW.HCA.TO  Human capital
# 1       NW.HCA.PC  Human capital
# 2  NW.HCA.FEMP.PC  Human capital
# 3  NW.HCA.MEMP.PC  Human capital
# 4  NW.HCA.FEMA.PC  Human capital
#
#                                       Indicator Name  \
# 0                  Human capital (constant 2018 US$)
# 1       Human capital per capita (constant 2018 US$)
# 2  Human capital per capita, employed female (con...
# 3  Human capital per capita, employed male (const...
# 4  Human capital per capita, female (constant 201...
#
#                                               Source
# 0  World Bank. 2021. The Changing Wealth of Natio...
# 1  World Bank. 2021. The Changing Wealth of Natio...
# 2  World Bank. 2021. The Changing Wealth of Natio...
# 3  World Bank. 2021. The Changing Wealth of Natio...
# 4  World Bank. 2021. The Changing Wealth of Natio...

# %%
songplay_table_create = ("""CREATE TABLE IF NOT EXISTS accountscountry(
    country_code VARCHAR,
    short_name VARCHAR,
    table_name VARCHAR,
    long_name VARCHAR,
    currency_unit VARCHAR
    )""")

# %%
conn.commit()

# %%
cur.execute(songplay_table_create)
conn.commit()

# %%
accounts_data_table_create = ("""CREATE TABLE IF NOT EXISTS accountsdata(
    country_name VARCHAR,
    country_code VARCHAR,
    indicator_name VARCHAR,
    indicator_code VARCHAR,
    year_1995 numeric,
    year_2000 numeric,
    year_2005 numeric,
    year_2010 numeric,
    year_2014 numeric
    )""")
cur.execute(accounts_data_table_create)
conn.commit()

# %%
accountseries_data_table_create = ("""CREATE TABLE IF NOT EXISTS accountseries(
    series_code VARCHAR,
    topic VARCHAR,
    indicator_name VARCHAR,
    source VARCHAR
    )""")
cur.execute(accountseries_data_table_create)
conn.commit()

# %%
accounts_country_table_insert = ("""INSERT INTO accountscountry(
                                country_code,
                                short_name,
                                table_name,
                                long_name,
                                currency_unit)
                                VALUES (%s,%s,%s,%s,%s)""")

# %%
for i, row in AccountsCountry_clean.iterrows():
    print(row)
# Out:
# Code                             ALB
# Short Name                   Albania
# Table Name                   Albania
# Long Name        Republic of Albania
# Currency Unit           Albanian lek
# Name: 0, dtype: object
# Code                            ARG
# Short Name                Argentina
# Table Name                Argentina
# Long Name        Argentine Republic
# Currency Unit        Argentine peso
# Name: 1, dtype: object
# Code                             ARM
# Short Name                   Armenia
# Table Name                   Armenia
# Long Name        Republic of Armenia
# Currency Unit          Armenian dram
# Name: 2, dtype: object
# Code                                   AUS
# Short Name                       Australia
# Table Name                       Australia
# Long Name        Commonwealth of Australia
# Currency Unit            Australian dollar
# Name: 3, dtype: object
# Code                             AUT
# Short Name                   Austria
# Table Name                   Austria
# Long Name        Republic of Austria
# Currency Unit                   Euro
# Name: 4, dtype: object
# Code                                AZE
# Short Name                   Azerbaijan
# Table Name                   Azerbaijan
# Long Name        Republic of Azerbaijan
# Currency Unit           New Azeri manat
# Name: 5, dtype: object
# Code                            BHR
# Short Name                  Bahrain
# Table Name                  Bahrain
# Long Name        Kingdom of Bahrain
# Currency Unit        Bahraini dinar
# Name: 6, dtype: object
# Code                                         BGD
# Short Name                            Bangladesh
# Table Name                            Bangladesh
# Long Name        People's Republic of Bangladesh
# Currency Unit                   Bangladeshi taka
# Name: 7, dtype: object
# Code                             BLR
# Short Name                   Belarus
# Table Name                   Belarus
# Long Name        Republic of Belarus
# Currency Unit       Belarusian rubel
# Name: 8, dtype: object
# Code                            BEL
# Short Name                  Belgium
# Table Name                  Belgium
# Long Name        Kingdom of Belgium
# Currency Unit                  Euro
# Name: 9, dtype: object
# Code                       BLZ
# Short Name              Belize
# Table Name              Belize
# Long Name               Belize
# Currency Unit    Belize dollar
# Name: 10, dtype: object
# Code                                BEN
# Short Name                        Benin
# Table Name                        Benin
# Long Name             Republic of Benin
# Currency Unit    West African CFA franc
# Name: 11, dtype: object
# Code                                        BOL
# Short Name                              Bolivia
# Table Name                              Bolivia
# Long Name        Plurinational State of Bolivia
# Currency Unit                Bolivian Boliviano
# Name: 12, dtype: object
# Code                                                 BIH
# Short Name                        Bosnia and Herzegovina
# Table Name                        Bosnia and Herzegovina
# Long Name                         Bosnia and Herzegovina
# Currency Unit    Bosnia and Herzegovina convertible mark
# Name: 13, dtype: object
# Code                              BWA
# Short Name                   Botswana
# Table Name                   Botswana
# Long Name        Republic of Botswana
# Currency Unit           Botswana pula
# Name: 14, dtype: object
# Code                                       BRA
# Short Name                              Brazil
# Table Name                              Brazil
# Long Name        Federative Republic of Brazil
# Currency Unit                   Brazilian real
# Name: 15, dtype: object
# Code                              BGR
# Short Name                   Bulgaria
# Table Name                   Bulgaria
# Long Name        Republic of Bulgaria
# Currency Unit           Bulgarian lev
# Name: 16, dtype: object
# Code                                BFA
# Short Name                 Burkina Faso
# Table Name                 Burkina Faso
# Long Name                  Burkina Faso
# Currency Unit    West African CFA franc
# Name: 17, dtype: object
# Code                             BDI
# Short Name                   Burundi
# Table Name                   Burundi
# Long Name        Republic of Burundi
# Currency Unit          Burundi franc
# Name: 18, dtype: object
# Code                             KHM
# Short Name                  Cambodia
# Table Name                  Cambodia
# Long Name        Kingdom of Cambodia
# Currency Unit         Cambodian riel
# Name: 19, dtype: object
# Code                                   CMR
# Short Name                        Cameroon
# Table Name                        Cameroon
# Long Name             Republic of Cameroon
# Currency Unit    Central African CFA franc
# Name: 20, dtype: object
# Code                         CAN
# Short Name                Canada
# Table Name                Canada
# Long Name                 Canada
# Currency Unit    Canadian dollar
# Name: 21, dtype: object
# Code                                   CAF
# Short Name        Central African Republic
# Table Name        Central African Republic
# Long Name         Central African Republic
# Currency Unit    Central African CFA franc
# Name: 22, dtype: object
# Code                                   TCD
# Short Name                            Chad
# Table Name                            Chad
# Long Name                 Republic of Chad
# Currency Unit    Central African CFA franc
# Name: 23, dtype: object
# Code                           CHL
# Short Name                   Chile
# Table Name                   Chile
# Long Name        Republic of Chile
# Currency Unit         Chilean peso
# Name: 24, dtype: object
# Code                                    CHN
# Short Name                            China
# Table Name                            China
# Long Name        People's Republic of China
# Currency Unit                  Chinese yuan
# Name: 25, dtype: object
# Code                              COL
# Short Name                   Colombia
# Table Name                   Colombia
# Long Name        Republic of Colombia
# Currency Unit          Colombian peso
# Name: 26, dtype: object
# Code                              COM
# Short Name                    Comoros
# Table Name                    Comoros
# Long Name        Union of the Comoros
# Currency Unit          Comorian franc
# Name: 27, dtype: object
# Code                                   COG
# Short Name                           Congo
# Table Name                     Congo, Rep.
# Long Name                Republic of Congo
# Currency Unit    Central African CFA franc
# Name: 28, dtype: object
# Code                                CRI
# Short Name                   Costa Rica
# Table Name                   Costa Rica
# Long Name        Republic of Costa Rica
# Currency Unit         Costa Rican colon
# Name: 29, dtype: object
# Code                                   CIV
# Short Name                   Côte d'Ivoire
# Table Name                   Côte d'Ivoire
# Long Name        Republic of Côte d'Ivoire
# Currency Unit       West African CFA franc
# Name: 30, dtype: object
# Code                             HRV
# Short Name                   Croatia
# Table Name                   Croatia
# Long Name        Republic of Croatia
# Currency Unit          Croatian kuna
# Name: 31, dtype: object
# Code                        CZE
# Short Name       Czech Republic
# Table Name       Czech Republic
# Long Name        Czech Republic
# Currency Unit      Czech koruna
# Name: 32, dtype: object
# Code                                          COD
# Short Name                        Dem. Rep. Congo
# Table Name                       Congo, Dem. Rep.
# Long Name        Democratic Republic of the Congo
# Currency Unit                     Congolese franc
# Name: 33, dtype: object
# Code                            DNK
# Short Name                  Denmark
# Table Name                  Denmark
# Long Name        Kingdom of Denmark
# Currency Unit          Danish krone
# Name: 34, dtype: object
# Code                              DJI
# Short Name                   Djibouti
# Table Name                   Djibouti
# Long Name        Republic of Djibouti
# Currency Unit          Djibouti franc
# Name: 35, dtype: object
# Code                            DOM
# Short Name       Dominican Republic
# Table Name       Dominican Republic
# Long Name        Dominican Republic
# Currency Unit        Dominican peso
# Name: 36, dtype: object
# Code                             ECU
# Short Name                   Ecuador
# Table Name                   Ecuador
# Long Name        Republic of Ecuador
# Currency Unit            U.S. dollar
# Name: 37, dtype: object
# Code                                EGY
# Short Name                        Egypt
# Table Name             Egypt, Arab Rep.
# Long Name        Arab Republic of Egypt
# Currency Unit            Egyptian pound
# Name: 38, dtype: object
# Code                                 SLV
# Short Name                   El Salvador
# Table Name                   El Salvador
# Long Name        Republic of El Salvador
# Currency Unit                U.S. dollar
# Name: 39, dtype: object
# Code                             EST
# Short Name                   Estonia
# Table Name                   Estonia
# Long Name        Republic of Estonia
# Currency Unit                   Euro
# Name: 40, dtype: object
# Code                             SWZ
# Short Name                  Eswatini
# Table Name                  Eswatini
# Long Name        Kingdom of Eswatini
# Currency Unit        Swazi lilangeni
# Name: 41, dtype: object
# Code                                                 ETH
# Short Name                                      Ethiopia
# Table Name                                      Ethiopia
# Long Name        Federal Democratic Republic of Ethiopia
# Currency Unit                             Ethiopian birr
# Name: 42, dtype: object
# Code                             FIN
# Short Name                   Finland
# Table Name                   Finland
# Long Name        Republic of Finland
# Currency Unit                   Euro
# Name: 43, dtype: object
# Code                         FRA
# Short Name                France
# Table Name                France
# Long Name        French Republic
# Currency Unit               Euro
# Name: 44, dtype: object
# Code                                   GAB
# Short Name                           Gabon
# Table Name                           Gabon
# Long Name                Gabonese Republic
# Currency Unit    Central African CFA franc
# Name: 45, dtype: object
# Code                       GEO
# Short Name             Georgia
# Table Name             Georgia
# Long Name              Georgia
# Currency Unit    Georgian lari
# Name: 46, dtype: object
# Code                                     DEU
# Short Name                           Germany
# Table Name                           Germany
# Long Name        Federal Republic of Germany
# Currency Unit                           Euro
# Name: 47, dtype: object
# Code                           GHA
# Short Name                   Ghana
# Table Name                   Ghana
# Long Name        Republic of Ghana
# Currency Unit    New Ghanaian cedi
# Name: 48, dtype: object
# Code                           GRC
# Short Name                  Greece
# Table Name                  Greece
# Long Name        Hellenic Republic
# Currency Unit                 Euro
# Name: 49, dtype: object
# Code                               GTM
# Short Name                   Guatemala
# Table Name                   Guatemala
# Long Name        Republic of Guatemala
# Currency Unit       Guatemalan quetzal
# Name: 50, dtype: object
# Code                            GIN
# Short Name                   Guinea
# Table Name                   Guinea
# Long Name        Republic of Guinea
# Currency Unit         Guinean franc
# Name: 51, dtype: object
# Code                                         GUY
# Short Name                                Guyana
# Table Name                                Guyana
# Long Name        Co-operative Republic of Guyana
# Currency Unit                      Guyana dollar
# Name: 52, dtype: object
# Code                           HTI
# Short Name                   Haiti
# Table Name                   Haiti
# Long Name        Republic of Haiti
# Currency Unit       Haitian gourde
# Name: 53, dtype: object
# Code                              HND
# Short Name                   Honduras
# Table Name                   Honduras
# Long Name        Republic of Honduras
# Currency Unit        Honduran lempira
# Name: 54, dtype: object
# Code                          HUN
# Short Name                Hungary
# Table Name                Hungary
# Long Name                 Hungary
# Currency Unit    Hungarian forint
# Name: 55, dtype: object
# Code                             ISL
# Short Name                   Iceland
# Table Name                   Iceland
# Long Name        Republic of Iceland
# Currency Unit          Iceland krona
# Name: 56, dtype: object
# Code                           IND
# Short Name                   India
# Table Name                   India
# Long Name        Republic of India
# Currency Unit         Indian rupee
# Name: 57, dtype: object
# Code                               IDN
# Short Name                   Indonesia
# Table Name                   Indonesia
# Long Name        Republic of Indonesia
# Currency Unit        Indonesian rupiah
# Name: 58, dtype: object
# Code                                  IRN
# Short Name                           Iran
# Table Name             Iran, Islamic Rep.
# Long Name        Islamic Republic of Iran
# Currency Unit                Iranian rial
# Name: 59, dtype: object
# Code                          IRQ
# Short Name                   Iraq
# Table Name                   Iraq
# Long Name        Republic of Iraq
# Currency Unit         Iraqi dinar
# Name: 60, dtype: object
# Code                 IRL
# Short Name       Ireland
# Table Name       Ireland
# Long Name        Ireland
# Currency Unit       Euro
# Name: 61, dtype: object
# Code                          ITA
# Short Name                  Italy
# Table Name                  Italy
# Long Name        Italian Republic
# Currency Unit                Euro
# Name: 62, dtype: object
# Code                         JAM
# Short Name               Jamaica
# Table Name               Jamaica
# Long Name                Jamaica
# Currency Unit    Jamaican dollar
# Name: 63, dtype: object
# Code                      JPN
# Short Name              Japan
# Table Name              Japan
# Long Name               Japan
# Currency Unit    Japanese yen
# Name: 64, dtype: object
# Code                                     JOR
# Short Name                            Jordan
# Table Name                            Jordan
# Long Name        Hashemite Kingdom of Jordan
# Currency Unit                Jordanian dinar
# Name: 65, dtype: object
# Code                                KAZ
# Short Name                   Kazakhstan
# Table Name                   Kazakhstan
# Long Name        Republic of Kazakhstan
# Currency Unit              Kazakh tenge
# Name: 66, dtype: object
# Code                           KEN
# Short Name                   Kenya
# Table Name                   Kenya
# Long Name        Republic of Kenya
# Currency Unit      Kenyan shilling
# Name: 67, dtype: object
# Code                           KOR
# Short Name                   Korea
# Table Name             Korea, Rep.
# Long Name        Republic of Korea
# Currency Unit           Korean won
# Name: 68, dtype: object
# Code                         KWT
# Short Name                Kuwait
# Table Name                Kuwait
# Long Name        State of Kuwait
# Currency Unit      Kuwaiti dinar
# Name: 69, dtype: object
# Code                         KGZ
# Short Name       Kyrgyz Republic
# Table Name       Kyrgyz Republic
# Long Name        Kyrgyz Republic
# Currency Unit         Kyrgyz som
# Name: 70, dtype: object
# Code                                          LAO
# Short Name                                Lao PDR
# Table Name                                Lao PDR
# Long Name        Lao People's Democratic Republic
# Currency Unit                             Lao kip
# Name: 71, dtype: object
# Code                            LVA
# Short Name                   Latvia
# Table Name                   Latvia
# Long Name        Republic of Latvia
# Currency Unit                  Euro
# Name: 72, dtype: object
# Code                           LBN
# Short Name                 Lebanon
# Table Name                 Lebanon
# Long Name        Lebanese Republic
# Currency Unit       Lebanese pound
# Name: 73, dtype: object
# Code                            LSO
# Short Name                  Lesotho
# Table Name                  Lesotho
# Long Name        Kingdom of Lesotho
# Currency Unit          Lesotho loti
# Name: 74, dtype: object
# Code                             LBR
# Short Name                   Liberia
# Table Name                   Liberia
# Long Name        Republic of Liberia
# Currency Unit            U.S. dollar
# Name: 75, dtype: object
# Code                               LTU
# Short Name                   Lithuania
# Table Name                   Lithuania
# Long Name        Republic of Lithuania
# Currency Unit                     Euro
# Name: 76, dtype: object
# Code                                   LUX
# Short Name                      Luxembourg
# Table Name                      Luxembourg
# Long Name        Grand Duchy of Luxembourg
# Currency Unit                         Euro
# Name: 77, dtype: object
# Code                                MDG
# Short Name                   Madagascar
# Table Name                   Madagascar
# Long Name        Republic of Madagascar
# Currency Unit           Malagasy ariary
# Name: 78, dtype: object
# Code                            MWI
# Short Name                   Malawi
# Table Name                   Malawi
# Long Name        Republic of Malawi
# Currency Unit         Malawi kwacha
# Name: 79, dtype: object
# Code                           MYS
# Short Name                Malaysia
# Table Name                Malaysia
# Long Name                 Malaysia
# Currency Unit    Malaysian ringgit
# Name: 80, dtype: object
# Code                              MDV
# Short Name                   Maldives
# Table Name                   Maldives
# Long Name        Republic of Maldives
# Currency Unit       Maldivian rufiyaa
# Name: 81, dtype: object
# Code                                MLI
# Short Name                         Mali
# Table Name                         Mali
# Long Name              Republic of Mali
# Currency Unit    West African CFA franc
# Name: 82, dtype: object
# Code                           MLT
# Short Name                   Malta
# Table Name                   Malta
# Long Name        Republic of Malta
# Currency Unit                 Euro
# Name: 83, dtype: object
# Code                                        MRT
# Short Name                           Mauritania
# Table Name                           Mauritania
# Long Name        Islamic Republic of Mauritania
# Currency Unit               Mauritanian ouguiya
# Name: 84, dtype: object
# Code                               MUS
# Short Name                   Mauritius
# Table Name                   Mauritius
# Long Name        Republic of Mauritius
# Currency Unit          Mauritian rupee
# Name: 85, dtype: object
# Code                               MEX
# Short Name                      Mexico
# Table Name                      Mexico
# Long Name        United Mexican States
# Currency Unit             Mexican peso
# Name: 86, dtype: object
# Code                             MDA
# Short Name                   Moldova
# Table Name                   Moldova
# Long Name        Republic of Moldova
# Currency Unit           Moldovan leu
# Name: 87, dtype: object
# Code                          MNG
# Short Name               Mongolia
# Table Name               Mongolia
# Long Name                Mongolia
# Currency Unit    Mongolian tugrik
# Name: 88, dtype: object
# Code                            MAR
# Short Name                  Morocco
# Table Name                  Morocco
# Long Name        Kingdom of Morocco
# Currency Unit       Moroccan dirham
# Name: 89, dtype: object
# Code                                MOZ
# Short Name                   Mozambique
# Table Name                   Mozambique
# Long Name        Republic of Mozambique
# Currency Unit    New Mozambican metical
# Name: 90, dtype: object
# Code                             NAM
# Short Name                   Namibia
# Table Name                   Namibia
# Long Name        Republic of Namibia
# Currency Unit        Namibian dollar
# Name: 91, dtype: object
# Code                        NPL
# Short Name                Nepal
# Table Name                Nepal
# Long Name                 Nepal
# Currency Unit    Nepalese rupee
# Name: 92, dtype: object
# Code                                    NLD
# Short Name                      Netherlands
# Table Name                      Netherlands
# Long Name        Kingdom of the Netherlands
# Currency Unit                          Euro
# Name: 93, dtype: object
# Code                                 NIC
# Short Name                     Nicaragua
# Table Name                     Nicaragua
# Long Name          Republic of Nicaragua
# Currency Unit    Nicaraguan gold cordoba
# Name: 94, dtype: object
# Code                                NER
# Short Name                        Niger
# Table Name                        Niger
# Long Name             Republic of Niger
# Currency Unit    West African CFA franc
# Name: 95, dtype: object
# Code                                     NGA
# Short Name                           Nigeria
# Table Name                           Nigeria
# Long Name        Federal Republic of Nigeria
# Currency Unit                 Nigerian naira
# Name: 96, dtype: object
# Code                                     MKD
# Short Name                   North Macedonia
# Table Name                   North Macedonia
# Long Name        Republic of North Macedonia
# Currency Unit               Macedonian denar
# Name: 97, dtype: object
# Code                           NOR
# Short Name                  Norway
# Table Name                  Norway
# Long Name        Kingdom of Norway
# Currency Unit      Norwegian krone
# Name: 98, dtype: object
# Code                           OMN
# Short Name                    Oman
# Table Name                    Oman
# Long Name        Sultanate of Oman
# Currency Unit           Omani rial
# Name: 99, dtype: object
# Code                                      PAK
# Short Name                           Pakistan
# Table Name                           Pakistan
# Long Name        Islamic Republic of Pakistan
# Currency Unit                 Pakistani rupee
# Name: 100, dtype: object
# Code                            PAN
# Short Name                   Panama
# Table Name                   Panama
# Long Name        Republic of Panama
# Currency Unit     Panamanian balboa
# Name: 101, dtype: object
# Code                                                   PNG
# Short Name                                Papua New Guinea
# Table Name                                Papua New Guinea
# Long Name        The Independent State of Papua New Guinea
# Currency Unit                        Papua New Guinea kina
# Name: 102, dtype: object
# Code                              PRY
# Short Name                   Paraguay
# Table Name                   Paraguay
# Long Name        Republic of Paraguay
# Currency Unit      Paraguayan guarani
# Name: 103, dtype: object
# Code                          PER
# Short Name                   Peru
# Table Name                   Peru
# Long Name        Republic of Peru
# Currency Unit    Peruvian new sol
# Name: 104, dtype: object
# Code                                     PHL
# Short Name                       Philippines
# Table Name                       Philippines
# Long Name        Republic of the Philippines
# Currency Unit                Philippine peso
# Name: 105, dtype: object
# Code                            POL
# Short Name                   Poland
# Table Name                   Poland
# Long Name        Republic of Poland
# Currency Unit          Polish zloty
# Name: 106, dtype: object
# Code                             PRT
# Short Name                  Portugal
# Table Name                  Portugal
# Long Name        Portuguese Republic
# Currency Unit                   Euro
# Name: 107, dtype: object
# Code                        QAT
# Short Name                Qatar
# Table Name                Qatar
# Long Name        State of Qatar
# Currency Unit      Qatari riyal
# Name: 108, dtype: object
# Code                          ROU
# Short Name                Romania
# Table Name                Romania
# Long Name                 Romania
# Currency Unit    New Romanian leu
# Name: 109, dtype: object
# Code                            RUS
# Short Name                   Russia
# Table Name       Russian Federation
# Long Name        Russian Federation
# Currency Unit         Russian ruble
# Name: 110, dtype: object
# Code                            RWA
# Short Name                   Rwanda
# Table Name                   Rwanda
# Long Name        Republic of Rwanda
# Currency Unit         Rwandan franc
# Name: 111, dtype: object
# Code                                 SAU
# Short Name                  Saudi Arabia
# Table Name                  Saudi Arabia
# Long Name        Kingdom of Saudi Arabia
# Currency Unit        Saudi Arabian riyal
# Name: 112, dtype: object
# Code                                SEN
# Short Name                      Senegal
# Table Name                      Senegal
# Long Name           Republic of Senegal
# Currency Unit    West African CFA franc
# Name: 113, dtype: object
# Code                                  SLE
# Short Name                   Sierra Leone
# Table Name                   Sierra Leone
# Long Name        Republic of Sierra Leone
# Currency Unit        Sierra Leonean leone
# Name: 114, dtype: object
# Code                               SGP
# Short Name                   Singapore
# Table Name                   Singapore
# Long Name        Republic of Singapore
# Currency Unit         Singapore dollar
# Name: 115, dtype: object
# Code                         SVK
# Short Name       Slovak Republic
# Table Name       Slovak Republic
# Long Name        Slovak Republic
# Currency Unit               Euro
# Name: 116, dtype: object
# Code                              SVN
# Short Name                   Slovenia
# Table Name                   Slovenia
# Long Name        Republic of Slovenia
# Currency Unit                    Euro
# Name: 117, dtype: object
# Code                                SLB
# Short Name              Solomon Islands
# Table Name              Solomon Islands
# Long Name               Solomon Islands
# Currency Unit    Solomon Islands dollar
# Name: 118, dtype: object
# Code                                  ZAF
# Short Name                   South Africa
# Table Name                   South Africa
# Long Name        Republic of South Africa
# Currency Unit          South African rand
# Name: 119, dtype: object
# Code                          ESP
# Short Name                  Spain
# Table Name                  Spain
# Long Name        Kingdom of Spain
# Currency Unit                Euro
# Name: 120, dtype: object
# Code                                                    LKA
# Short Name                                        Sri Lanka
# Table Name                                        Sri Lanka
# Long Name        Democratic Socialist Republic of Sri Lanka
# Currency Unit                              Sri Lankan rupee
# Name: 121, dtype: object
# Code                              SUR
# Short Name                   Suriname
# Table Name                   Suriname
# Long Name        Republic of Suriname
# Currency Unit         Suriname dollar
# Name: 122, dtype: object
# Code                           SWE
# Short Name                  Sweden
# Table Name                  Sweden
# Long Name        Kingdom of Sweden
# Currency Unit        Swedish krona
# Name: 123, dtype: object
# Code                     CHE
# Short Name       Switzerland
# Table Name       Switzerland
# Long Name        Switzerland
# Currency Unit    Swiss franc
# Name: 124, dtype: object
# Code                                TJK
# Short Name                   Tajikistan
# Table Name                   Tajikistan
# Long Name        Republic of Tajikistan
# Currency Unit              Tajik somoni
# Name: 125, dtype: object
# Code                                     TZA
# Short Name                          Tanzania
# Table Name                          Tanzania
# Long Name        United Republic of Tanzania
# Currency Unit             Tanzanian shilling
# Name: 126, dtype: object
# Code                             THA
# Short Name                  Thailand
# Table Name                  Thailand
# Long Name        Kingdom of Thailand
# Currency Unit              Thai baht
# Name: 127, dtype: object
# Code                                GMB
# Short Name                   The Gambia
# Table Name                  Gambia, The
# Long Name        Republic of The Gambia
# Currency Unit            Gambian dalasi
# Name: 128, dtype: object
# Code                                TGO
# Short Name                         Togo
# Table Name                         Togo
# Long Name              Republic of Togo
# Currency Unit    West African CFA franc
# Name: 129, dtype: object
# Code                                         TTO
# Short Name                   Trinidad and Tobago
# Table Name                   Trinidad and Tobago
# Long Name        Republic of Trinidad and Tobago
# Currency Unit         Trinidad and Tobago dollar
# Name: 130, dtype: object
# Code                             TUN
# Short Name                   Tunisia
# Table Name                   Tunisia
# Long Name        Republic of Tunisia
# Currency Unit         Tunisian dinar
# Name: 131, dtype: object
# Code                            TUR
# Short Name                   Turkey
# Table Name                   Turkey
# Long Name        Republic of Turkey
# Currency Unit      New Turkish lira
# Name: 132, dtype: object
# Code                           TKM
# Short Name            Turkmenistan
# Table Name            Turkmenistan
# Long Name             Turkmenistan
# Currency Unit    New Turkmen manat
# Name: 133, dtype: object
# Code                            UGA
# Short Name                   Uganda
# Table Name                   Uganda
# Long Name        Republic of Uganda
# Currency Unit      Ugandan shilling
# Name: 134, dtype: object
# Code                           UKR
# Short Name                 Ukraine
# Table Name                 Ukraine
# Long Name                  Ukraine
# Currency Unit    Ukrainian hryvnia
# Name: 135, dtype: object
# Code                              ARE
# Short Name       United Arab Emirates
# Table Name       United Arab Emirates
# Long Name        United Arab Emirates
# Currency Unit           U.A.E. dirham
# Name: 136, dtype: object
# Code                                                           GBR
# Short Name                                          United Kingdom
# Table Name                                          United Kingdom
# Long Name        United Kingdom of Great Britain and Northern I...
# Currency Unit                                       Pound sterling
# Name: 137, dtype: object
# Code                                  USA
# Short Name                  United States
# Table Name                  United States
# Long Name        United States of America
# Currency Unit                 U.S. dollar
# Name: 138, dtype: object
# Code                                      URY
# Short Name                            Uruguay
# Table Name                            Uruguay
# Long Name        Oriental Republic of Uruguay
# Currency Unit                  Uruguayan peso
# Name: 139, dtype: object
# Code                                            VEN
# Short Name                                Venezuela
# Table Name                            Venezuela, RB
# Long Name        República Bolivariana de Venezuela
# Currency Unit             Venezuelan bolivar fuerte
# Name: 140, dtype: object
# Code                                       VNM
# Short Name                             Vietnam
# Table Name                             Vietnam
# Long Name        Socialist Republic of Vietnam
# Currency Unit                  Vietnamese dong
# Name: 141, dtype: object
# Code                            PSE
# Short Name       West Bank and Gaza
# Table Name       West Bank and Gaza
# Long Name        West Bank and Gaza
# Currency Unit    Israeli new shekel
# Name: 142, dtype: object
# Code                           YEM
# Short Name                   Yemen
# Table Name             Yemen, Rep.
# Long Name        Republic of Yemen
# Currency Unit          Yemeni rial
# Name: 143, dtype: object
# Code                            ZMB
# Short Name                   Zambia
# Table Name                   Zambia
# Long Name        Republic of Zambia
# Currency Unit    New Zambian kwacha
# Name: 144, dtype: object
# Code                              ZWE
# Short Name                   Zimbabwe
# Table Name                   Zimbabwe
# Long Name        Republic of Zimbabwe
# Currency Unit             U.S. dollar
# Name: 145, dtype: object

# %%
conn.commit()

# %%
for i, row in AccountsCountry_clean.iterrows():
    cur.execute(accounts_country_table_insert, list(row))
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# c:\Users\Admin\Desktop\VSCode\Git\wealth-project\connect-database.ipynb Cell 20 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/VSCode/Git/wealth-project/connect-database.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> for i, row in AccountsCountry_clean.iterrows():
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/VSCode/Git/wealth-project/connect-database.ipynb#X25sZmlsZQ%3D%3D?line=1'>2</a>     cur.execute(accounts_country_table_insert, list(row))
#
# UniqueViolation: duplicate key value violates unique constraint "accountscountry_pkey"
# DETAIL:  Key (country_code)=(ALB) already exists.

# %%
accounts_data_table_insert = ("""INSERT INTO accountsdata(
                                country_name,
                                country_code,
                                indicator_name,
                                indicator_code,
                                year_1995,
                                year_2000,
                                year_2005,
                                year_2010,
                                year_2014)
                                VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)""")

# %%
for i, row in AccountsData.iterrows():
    cur.execute(accounts_data_table_insert, list(row))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Admin\Desktop\VSCode\Git\wealth-project\connect-database.ipynb Cell 22 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/VSCode/Git/wealth-project/connect-database.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> for i, row in AccountsData.iterrows():
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Admin/Desktop/VSCode/Git/wealth-project/connect-database.ipynb#X30sZmlsZQ%3D%3D?line=1'>2</a>     cur.execute(accounts_data_table_insert, list(row))
#
# TypeError: not all arguments converted during string formatting
