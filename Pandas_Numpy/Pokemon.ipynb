# %%
# %matplotlib inline
 
import pandas as pd
import matplotlib.pyplot as plt
import random

# %%
csv_path='pokemon.csv'

# %%
df=pd.read_csv(csv_path)
df.head(100)
# Out:
#      #                   Name  Type 1  Type 2  Total   HP  Attack  Defense  \
# 0    1              Bulbasaur   Grass  Poison    318   45      49       49
# 1    2                Ivysaur   Grass  Poison    405   60      62       63
# 2    3               Venusaur   Grass  Poison    525   80      82       83
# 3    3  VenusaurMega Venusaur   Grass  Poison    625   80     100      123
# 4    4             Charmander    Fire     NaN    309   39      52       43
# ..  ..                    ...     ...     ...    ...  ...     ...      ...
# 95  88                 Grimer  Poison     NaN    325   80      80       50
# 96  89                    Muk  Poison     NaN    500  105     105       75
# 97  90               Shellder   Water     NaN    305   30      65      100
# 98  91               Cloyster   Water     Ice    525   50      95      180
# 99  92                 Gastly   Ghost  Poison    310   30      35       30
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0        65       65     45           1      False
# 1        80       80     60           1      False
# 2       100      100     80           1      False
# 3       122      120     80           1      False
# 4        60       50     65           1      False
# ..      ...      ...    ...         ...        ...
# 95       40       50     25           1      False
# 96       65      100     50           1      False
# 97       45       25     40           1      False
# 98       85       45     70           1      False
# 99      100       35     80           1      False
#
# [100 rows x 13 columns]

# %%
x=df[['Name']]

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
df1=df[df['HP']>50]
df1.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 5  5             Charmeleon   Fire     NaN    405  58      64       58
# 6  6              Charizard   Fire  Flying    534  78      84       78
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False

# %%
df1.to_csv('Pokemonhp_50.csv')

# %%
# Xem chiều dài của df, tương đương shape[0]
print('Len:', len(csv_path))
# Xem thông tin dataframe vừa đọc được
csv_path.info()
# Xem kích thước của dataframe
print('Shape:', csv_path.shape)
# Out:
# Len: 11
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-fa5825fbd6d8> in <module>
#       2 print('Len:', len(csv_path))
#       3 # Xem thông tin dataframe vừa đọc được
# ----> 4 csv_path.info()
#       5 # Xem kích thước của dataframe
#       6 print('Shape:', csv_path.shape)
#
# AttributeError: 'str' object has no attribute 'info'

# %%
csv_path['Type 1']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-38d348396572> in <module>
# ----> 1 csv_path['Type 1']
#
# TypeError: string indices must be integers
